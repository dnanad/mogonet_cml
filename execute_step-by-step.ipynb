# %% [markdown]
# # Step: 1 Data Preprocessing
# Steps:
# 1. Import and process the data
# 2. Find the common sample ids
# 3. Save the common sample ids
# 4. Save the labels
# 5. Save the features
# 6. Train test split
# 7. Save the train and test data
# 8. Differential analysis
# 9. Filter omic feature using the differential analysis results
# 10. Save the filtered differential analysis results
# 11. Split the omic data into train and test
# 12. Normalize the omic data with respect to the train data
# 13. Transform the test data with respect to the train data
# 14. Save the train and test data
# 15. Stag the all the omics data for CML
# 14. Save the train and test data for CML
# 15. Save the common features for CML
# 16. Save the labels for CML

# %%
# !python3 preprocessing.py --data_folder "0_new_data_0.05" \
                        --stratify \
                        --strat_col_list '["Trimester", "fetal_near_miss"]' \
                        --test_size 0.2 \
                        --omic_normalize_dict '{"1": true, "2": true}' \
                        --da_omics_dict '{"1": true, "2": true}' \
                        --filter_wrt_dict '{"1": "p-value(f-test)", "2": "p-value(f-test)"}' \
                        --method_dict '{"1": "bonferroni", "2": "bonferroni"}' \
                        --da_threshold_dict '{"1": 0.05, "2": 0.2}' \
                        --CV \
                        --n_splits 5
# Out:
# Preprocessing with the following parameters:
# Data Folder: 0_new_data_0.05
# Stratify: True
# Stratification Columns: ['Trimester', 'fetal_near_miss']
# Test Size: 0.2
# Omic Normalize Dict: {1: True, 2: True}
# DA Omics Dict: {1: True, 2: True}
# Filter With Respect Dict: {1: 'p-value(f-test)', 2: 'p-value(f-test)'}
# Method Dict: {1: 'bonferroni', 2: 'bonferroni'}
# DA Threshold Dict: {1: 0.05, 2: 0.2}
# Cross Validation: True
# Number of Splits: 5
# Sample ids saved as pickle file at:  /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/samples
# Filtering omic data for omic: 1
# Filtering omic data for omic: 2
# Cross validation
# Splitting the id data into train and test
# Split:  0
# For cv split 0: Splitting the omic data into train and test saving them plus saving the respective features
# Split:  1
# For cv split 1: Splitting the omic data into train and test saving them plus saving the respective features
# Split:  2
# For cv split 2: Splitting the omic data into train and test saving them plus saving the respective features
# Split:  3
# For cv split 3: Splitting the omic data into train and test saving them plus saving the respective features
# Split:  4
# For cv split 4: Splitting the omic data into train and test saving them plus saving the respective features
# Training set saved as ` 1_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 1_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Training set saved as ` 2_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 2_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Split 0: Saving the dataframes for CML
# Split 0: Saving the dataframes for labels
# Labels for training set saved as `labels_tr.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_0
# Label for test set saved as `labels_te.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_0
# Training set saved as ` 1_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 1_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Training set saved as ` 2_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 2_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Split 1: Saving the dataframes for CML
# Split 1: Saving the dataframes for labels
# Labels for training set saved as `labels_tr.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_1
# Label for test set saved as `labels_te.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_1
# Training set saved as ` 1_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 1_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Training set saved as ` 2_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 2_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Split 2: Saving the dataframes for CML
# Split 2: Saving the dataframes for labels
# Labels for training set saved as `labels_tr.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_2
# Label for test set saved as `labels_te.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_2
# Training set saved as ` 1_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 1_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Training set saved as ` 2_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 2_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Split 3: Saving the dataframes for CML
# Split 3: Saving the dataframes for labels
# Labels for training set saved as `labels_tr.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_3
# Label for test set saved as `labels_te.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_3
# Training set saved as ` 1_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 1_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Training set saved as ` 2_tr.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Test set saved as` 2_te.csv in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV
# Split 4: Saving the dataframes for CML
# Split 4: Saving the dataframes for labels
# Labels for training set saved as `labels_tr.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_4
# Label for test set saved as `labels_te.csv` in the folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_4
# Preprocessing completed!

# %% [markdown]
# # Step 2.1: MOGOGET Training and Testing

# %%
# !python3 mogonet.py --data_folder "0_new_data_0.05"\
    --stratify \
    --CV \
    --n_splits 5 \
    --num_epoch_pretrain 400 \
    --num_epoch 1200 \
    --test_interval 50 \
    --lr_e_pretrain 1e-3 \
    --lr_e 5e-3 \
    --lr_c 1e-3 \
    --num_class 2 \
    --adj_parameter 2 \
    --dim_he_list '[200, 200, 100]'
# Out:
# Running MOGONET
# Data folder:  0_new_data_0.05
# Stratify:  True
# CV:  True
# Number of splits:  5
# Number of pretrain epochs:  400
# Number of epochs:  1200
# Test interval:  50
# Learning rate for pretraining:  0.001
# Learning rate for encoder:  0.005
# Learning rate for classifier:  0.001
# Number of classes:  2
# Adjacency parameter:  2
# Dimension list for hidden layers:  [200, 200, 100]
#
# Pretrain GCNs...
# Preptarin epoch 0
# Preptarin epoch 50
# Preptarin epoch 100
# Preptarin epoch 150
# Preptarin epoch 200
# Preptarin epoch 250
# Preptarin epoch 300
# Preptarin epoch 350
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.241
# Test F1: 0.214
# Test AUC: 0.564
#
# Test: Epoch 50
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.692
#
# Test: Epoch 100
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.692
#
# Test: Epoch 150
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.692
#
# Test: Epoch 200
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 250
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.667
#
# Test: Epoch 300
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 350
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 400
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 450
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.692
#
# Test: Epoch 500
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 550
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.551
#
# Test: Epoch 600
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 650
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.603
#
# Test: Epoch 700
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.577
#
# Test: Epoch 750
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 800
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 850
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 900
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.705
#
# Test: Epoch 950
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 1000
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.564
#
# Test: Epoch 1050
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 1100
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.603
#
# Test: Epoch 1150
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 1200
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.564
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Total number of samples in test set: 29
# Recall: 0.00000
# Precision: 0.00000
# ACC: 0.897
# F1: 0.00000
# Precision Recall F1 Support:
#  (array([0.89655172, 0.        ]), array([1., 0.]), array([0.94545455, 0.        ]), array([26,  3]))
# AUC: 0.564
# Confusion Matrix:
#  [[26  0]
#  [ 3  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200/20250224-160935/CV_0/mogonet_CV_0_lift.png
#
# Training finished!
# Figure(640x480)
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# Pretrain GCNs...
# Preptarin epoch 0
# Preptarin epoch 50
# Preptarin epoch 100
# Preptarin epoch 150
# Preptarin epoch 200
# Preptarin epoch 250
# Preptarin epoch 300
# Preptarin epoch 350
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.103
# Test F1: 0.188
# Test AUC: 0.449
#
# Test: Epoch 50
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.667
#
# Test: Epoch 100
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 150
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 200
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.577
#
# Test: Epoch 250
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 300
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.513
#
# Test: Epoch 350
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 400
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.538
#
# Test: Epoch 450
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 500
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 550
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 600
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.577
#
# Test: Epoch 650
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.551
#
# Test: Epoch 700
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.654
#
# Test: Epoch 750
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.603
#
# Test: Epoch 800
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.615
#
# Test: Epoch 850
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 900
# Test ACC: 0.897
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 950
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 1000
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.641
#
# Test: Epoch 1050
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.679
#
# Test: Epoch 1100
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.628
#
# Test: Epoch 1150
# Test ACC: 0.793
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 1200
# Test ACC: 0.793
# Test F1: 0.000
# Test AUC: 0.615
# Total number of samples in test set: 29
# Recall: 0.00000
# Precision: 0.00000
# ACC: 0.793
# F1: 0.00000
# Precision Recall F1 Support:
#  (array([0.88461538, 0.        ]), array([0.88461538, 0.        ]), array([0.88461538, 0.        ]), array([26,  3]))
# AUC: 0.615
# Confusion Matrix:
#  [[23  3]
#  [ 3  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200/20250224-160935/CV_1/mogonet_CV_1_lift.png
#
# Training finished!
# Figure(640x480)
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# Pretrain GCNs...
# Preptarin epoch 0
# Preptarin epoch 50
# Preptarin epoch 100
# Preptarin epoch 150
# Preptarin epoch 200
# Preptarin epoch 250
# Preptarin epoch 300
# Preptarin epoch 350
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.724
# Test F1: 0.200
# Test AUC: 0.650
#
# Test: Epoch 50
# Test ACC: 0.207
# Test F1: 0.207
# Test AUC: 0.500
#
# Test: Epoch 100
# Test ACC: 0.517
# Test F1: 0.222
# Test AUC: 0.400
#
# Test: Epoch 150
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.660
#
# Test: Epoch 200
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.450
#
# Test: Epoch 250
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.180
#
# Test: Epoch 300
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.370
#
# Test: Epoch 350
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.410
#
# Test: Epoch 400
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.350
#
# Test: Epoch 450
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.240
#
# Test: Epoch 500
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.390
#
# Test: Epoch 550
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.230
#
# Test: Epoch 600
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.390
#
# Test: Epoch 650
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.330
#
# Test: Epoch 700
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.560
#
# Test: Epoch 750
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.560
#
# Test: Epoch 800
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
#
# Test: Epoch 850
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
#
# Test: Epoch 900
# Test ACC: 0.828
# Test F1: 0.000
# Test AUC: 0.440
#
# Test: Epoch 950
# Test ACC: 0.828
# Test F1: 0.000
# Test AUC: 0.450
#
# Test: Epoch 1000
# Test ACC: 0.759
# Test F1: 0.000
# Test AUC: 0.530
#
# Test: Epoch 1050
# Test ACC: 0.793
# Test F1: 0.000
# Test AUC: 0.350
#
# Test: Epoch 1100
# Test ACC: 0.759
# Test F1: 0.000
# Test AUC: 0.460
#
# Test: Epoch 1150
# Test ACC: 0.759
# Test F1: 0.000
# Test AUC: 0.530
#
# Test: Epoch 1200
# Test ACC: 0.759
# Test F1: 0.000
# Test AUC: 0.580
# Total number of samples in test set: 29
# Recall: 0.00000
# Precision: 0.00000
# ACC: 0.759
# F1: 0.00000
# Precision Recall F1 Support:
#  (array([0.84615385, 0.        ]), array([0.88, 0.  ]), array([0.8627451, 0.       ]), array([25,  4]))
# AUC: 0.580
# Confusion Matrix:
#  [[22  3]
#  [ 4  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200/20250224-160935/CV_2/mogonet_CV_2_lift.png
#
# Training finished!
# Figure(640x480)
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# Pretrain GCNs...
# Preptarin epoch 0
# Preptarin epoch 50
# Preptarin epoch 100
# Preptarin epoch 150
# Preptarin epoch 200
# Preptarin epoch 250
# Preptarin epoch 300
# Preptarin epoch 350
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.375
#
# Test: Epoch 50
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.510
#
# Test: Epoch 100
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.500
#
# Test: Epoch 150
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.490
#
# Test: Epoch 200
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.470
#
# Test: Epoch 250
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
#
# Test: Epoch 300
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.510
#
# Test: Epoch 350
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.520
#
# Test: Epoch 400
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.480
#
# Test: Epoch 450
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.510
#
# Test: Epoch 500
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.590
#
# Test: Epoch 550
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.570
#
# Test: Epoch 600
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.500
#
# Test: Epoch 650
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
#
# Test: Epoch 700
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.460
#
# Test: Epoch 750
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.480
#
# Test: Epoch 800
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.450
#
# Test: Epoch 850
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.550
#
# Test: Epoch 900
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.550
#
# Test: Epoch 950
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.530
#
# Test: Epoch 1000
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.550
#
# Test: Epoch 1050
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.480
#
# Test: Epoch 1100
# Test ACC: 0.828
# Test F1: 0.000
# Test AUC: 0.490
#
# Test: Epoch 1150
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
#
# Test: Epoch 1200
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.540
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Total number of samples in test set: 29
# Recall: 0.00000
# Precision: 0.00000
# ACC: 0.862
# F1: 0.00000
# Precision Recall F1 Support:
#  (array([0.86206897, 0.        ]), array([1., 0.]), array([0.92592593, 0.        ]), array([25,  4]))
# AUC: 0.540
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200/20250224-160935/CV_3/mogonet_CV_3_lift.png
#
# Training finished!
# Figure(640x480)
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# Pretrain GCNs...
# Preptarin epoch 0
# Preptarin epoch 50
# Preptarin epoch 100
# Preptarin epoch 150
# Preptarin epoch 200
# Preptarin epoch 250
# Preptarin epoch 300
# Preptarin epoch 350
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.750
#
# Test: Epoch 50
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.610
#
# Test: Epoch 100
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.610
#
# Test: Epoch 150
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.570
#
# Test: Epoch 200
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.420
#
# Test: Epoch 250
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.410
#
# Test: Epoch 300
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.430
#
# Test: Epoch 350
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.430
#
# Test: Epoch 400
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.410
#
# Test: Epoch 450
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.500
#
# Test: Epoch 500
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.330
#
# Test: Epoch 550
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.580
#
# Test: Epoch 600
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.490
#
# Test: Epoch 650
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.500
#
# Test: Epoch 700
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.530
#
# Test: Epoch 750
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.290
#
# Test: Epoch 800
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.560
#
# Test: Epoch 850
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.580
#
# Test: Epoch 900
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.510
#
# Test: Epoch 950
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.780
#
# Test: Epoch 1000
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.690
#
# Test: Epoch 1050
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.730
#
# Test: Epoch 1100
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.760
#
# Test: Epoch 1150
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.810
#
# Test: Epoch 1200
# Test ACC: 0.862
# Test F1: 0.000
# Test AUC: 0.740
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Total number of samples in test set: 29
# Recall: 0.00000
# Precision: 0.00000
# ACC: 0.862
# F1: 0.00000
# Precision Recall F1 Support:
#  (array([0.86206897, 0.        ]), array([1., 0.]), array([0.92592593, 0.        ]), array([25,  4]))
# AUC: 0.740
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200/20250224-160935/CV_4/mogonet_CV_4_lift.png
#
# Training finished!
# Figure(640x480)
# Figure(800x800)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)

# %% [markdown]
# # Step 2.2: CML Training and Testing

# %%
# !python3 cml.py --data_folder "0_new_data_0.05" \
            --cml_models '["XGBC", "DTC", "RFC", "SVC", "LRC", "ElasticNet"]' \
            --n_splits 5 \
            --CV \
            --stratify \
            --no_test_mode
# Out:
# Running CML model training
# Data folder: 0_new_data_0.05
# CML model: XGBC
# Number of splits: 5
# CV: True
# Stratify: True
# Test mode: False
# exp. name =XGBC_gridsearch_20250224-164050
# Cross validation
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_0
#
# Training the model for the trial 0 :
# Performing a gridsearch
#  - best model parameters:{'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 150}
# Predicting and evaluating...
# test scores: ACC = 0.931, F1 = 0.500, AUC = 0.667, (n:29)
# Confusion Matrix:
#  [[26  0]
#  [ 2  1]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_0/XGBC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 0 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_0
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_1
#
# Training the model for the trial 1 :
# Performing a gridsearch
#  - best model parameters:{'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 50}
# Predicting and evaluating...
# test scores: ACC = 0.897, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[26  0]
#  [ 3  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_1/XGBC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 1 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_1
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_2
#
# Training the model for the trial 2 :
# Performing a gridsearch
#  - best model parameters:{'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 50}
# Predicting and evaluating...
# test scores: ACC = 0.862, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_2/XGBC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 2 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_2
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_3
#
# Training the model for the trial 3 :
# Performing a gridsearch
#  - best model parameters:{'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 50}
# Predicting and evaluating...
# test scores: ACC = 0.862, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_3/XGBC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 3 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_3
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_4
#
# Training the model for the trial 4 :
# Performing a gridsearch
#  - best model parameters:{'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 50}
# Predicting and evaluating...
# test scores: ACC = 0.862, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_4/XGBC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 4 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050/CV_4
#
# Saved the scores in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/XGBC_gridsearch_20250224-164050
# Running CML model training
# Data folder: 0_new_data_0.05
# CML model: DTC
# Number of splits: 5
# CV: True
# Stratify: True
# Test mode: False
# exp. name =DTC_gridsearch_20250224-165711
# Cross validation
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_0
#
# Training the model for the trial 0 :
# Performing a gridsearch
#  - best model parameters:{'model__max_depth': 3, 'model__min_impurity_decrease': 0.01, 'model__min_samples_split': 100}
# Predicting and evaluating...
# test scores: ACC = 0.793, F1 = 0.000, AUC = 0.442, (n:29)
# Confusion Matrix:
#  [[23  3]
#  [ 3  0]]
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/scikitplot/metrics.py:115: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(1, 1, figsize=figsize)
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_0/DTC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 0 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_0
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_1
#
# Training the model for the trial 1 :
# Performing a gridsearch
#  - best model parameters:{'model__max_depth': 3, 'model__min_impurity_decrease': 0.01, 'model__min_samples_split': 100}
# Predicting and evaluating...
# test scores: ACC = 0.793, F1 = 0.000, AUC = 0.442, (n:29)
# Confusion Matrix:
#  [[23  3]
#  [ 3  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_1/DTC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 1 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_1
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_2
#
# Training the model for the trial 2 :
# Performing a gridsearch
#  - best model parameters:{'model__max_depth': 3, 'model__min_impurity_decrease': 0.01, 'model__min_samples_split': 100}
# Predicting and evaluating...
# test scores: ACC = 0.690, F1 = 0.000, AUC = 0.400, (n:29)
# Confusion Matrix:
#  [[20  5]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_2/DTC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 2 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_2
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_3
#
# Training the model for the trial 3 :
# Performing a gridsearch
#  - best model parameters:{'model__max_depth': 3, 'model__min_impurity_decrease': 0.01, 'model__min_samples_split': 100}
# Predicting and evaluating...
# test scores: ACC = 0.862, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_3/DTC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 3 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_3
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_4
#
# Training the model for the trial 4 :
# Performing a gridsearch
#  - best model parameters:{'model__max_depth': 3, 'model__min_impurity_decrease': 0.01, 'model__min_samples_split': 100}
# Predicting and evaluating...
# test scores: ACC = 0.724, F1 = 0.333, AUC = 0.630, (n:29)
# Confusion Matrix:
#  [[19  6]
#  [ 2  2]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_4/DTC_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 4 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711/CV_4
#
# Saved the scores in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/DTC_gridsearch_20250224-165711
# Running CML model training
# Data folder: 0_new_data_0.05
# CML model: RFC
# Number of splits: 5
# CV: True
# Stratify: True
# Test mode: False
# exp. name =RFC_gridsearch_20250224-165850
# Cross validation
# /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/CV_0
#
# Training the model for the trial 0 :
# Performing a gridsearch
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/pipeline.py:405: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# ...
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#  - best model parameters:{'model__l1_ratio': 1, 'model__max_iter': 2000, 'model__penalty': 'elasticnet', 'model__solver': 'saga'}
# Predicting and evaluating...
# test scores: ACC = 0.862, F1 = 0.000, AUC = 0.500, (n:29)
# Confusion Matrix:
#  [[25  0]
#  [ 4  0]]
# Saved figure: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/ElasticNet_gridsearch_20250224-171838/CV_4/ElasticNet_gridsearch_0_gain_lift.png
#
# Saved the options, scores and pipeline for trial 4 in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/ElasticNet_gridsearch_20250224-171838/CV_4
#
# Saved the scores in: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/CML/ElasticNet_gridsearch_20250224-171838

# %% [markdown]
# # Step 3: Results aggregation

# %%
# !python3 result_aggregator.py --data_folder "0_new_data_0.05" \
                            --CV \
                            --stratify \
                            --num_epoch_pretrain 400 \
                            --num_epoch 1200
# Out:
# Aggregating results
# Data folder: 0_new_data_0.05
# CV: True
# Stratify: True
# Number of pretrain epochs: 400
# Number of epochs: 1200
# Final scores saved at:  /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/results/final_scores_strat_CV.csv
# /Users/anand/Documents/projects/mogonet_cml/mogonet_cml-venv/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:0'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Saved figure at:  /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/results/new_data_orig_0.05strat_CV.png
# Figure(800x600)

# %% [markdown]
# # Step 4: Biomarker identification

# %%
# !python3 biomarker.py --data_folder "0_new_data_0.05" \
                    --stratify \
                    --CV \
                    --n_splits 5 \
                    --num_epoch_pretrain 400 \
                    --num_epoch 1200 \
                    --num_class 2 \
                    --adj_parameter 2 \
                    --dim_he_list "[200, 200, 100]"
# Out:
# Calculating feature importance
# Data folder: 0_new_data_0.05
# Stratify: True
# CV: True
# Number of splits: 5
# Number of pretrain epochs: 400
# Number of epochs: 1200
# Model folder: /Users/anand/Documents/projects/mogonet_cml/data/0_new_data_0.05/strat/CV/models/400_1200
# ['20250224-160935']
# Module E1 loaded!
# Module C1 loaded!
# Module E2 loaded!
# Module C2 loaded!
# Module C loaded!
# ^C
# KeyboardInterrupt

# %% [markdown]
# # Run everything in the following order:
# ### 1. Data Preprocessing
# ### 2. MOGOGET Training and Testing
# ### 3. CML Training and Testing
# ### 4. Results aggregation

# %%
# !python3 main.py --data_folder "0_new_data" \
                --stratify \
                --CV \
                --n_splits 5 \
                --num_epoch_pretrain 400 \
                --num_epoch 1200 \
                --test_interval 50 \
                --lr_e_pretrain 1e-3 \
                --lr_e 5e-3 \
                --lr_c 1e-3 \
                --num_class 2 \
                --adj_parameter 2 \
                --dim_he_list "[200, 200, 100]"
